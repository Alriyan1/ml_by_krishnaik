# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Algerian_forest_fires_dataset_UPDATE.csv')
df.head()
# Out:
#    day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           32   71   12    0.7  57.1  2.5   8.2  0.6  2.8
# 1    2      6  2012           30   73   13    4.0  55.7  2.7   7.8  0.6  2.9
# 2    3      6  2012           29   80   14    2.0  48.7  2.2   7.6  0.3  2.6
# 3    4      6  2012           30   64   14    0.0  79.4  5.2  15.4  2.2  5.6
# 4    5      6  2012           32   60   14    0.2  77.1  6.0  17.6  1.8  6.5
#
#    FWI    Classes
# 0  0.2  not fire
# 1  0.2  not fire
# 2  0.1  not fire
# 3    1  not fire
# 4  0.9  not fire

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          122 non-null    int64
#  1   month        122 non-null    int64
#  2   year         122 non-null    int64
#  3   Temperature  122 non-null    int64
#  4    RH          122 non-null    int64
#  5    Ws          122 non-null    int64
#  6   Rain         122 non-null    float64
#  7   FFMC         122 non-null    float64
#  8   DMC          122 non-null    float64
#  9   DC           122 non-null    object
#  10  ISI          122 non-null    float64
#  11  BUI          122 non-null    float64
#  12  FWI          122 non-null    object
#  13  Classes      121 non-null    object
# dtypes: float64(5), int64(6), object(3)
# memory usage: 13.5+ KB

# %%
df.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
#  RH            0
#  Ws            0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        1
# dtype: int64

# %%
df[df['Classes  '].isnull()==True]
# Out:
#     day  month  year  Temperature   RH   Ws  Rain   FFMC   DMC      DC   ISI  \
# 43   14      7  2012           37   37   18    0.2  88.9  12.9  14.6 9  12.5
#
#      BUI      FWI Classes
# 43  10.4  fire          NaN

# %%
df['Classes  '].value_counts()
# Out:
# fire             78
# not fire         41
# not fire          1
# not fire          1
# Name: Classes  , dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
#  RH            0
#  Ws            0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# dtype: int64

# %%
df1=pd.read_csv('Sidi-Bel Abbes Region ForestFire Dataset.csv')
df1.head()
# Out:
#    day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           32   71   12    0.7  57.1  2.5   8.2  0.6  2.8
# 1    2      6  2012           30   73   13    4.0  55.7  2.7   7.8  0.6  2.9
# 2    3      6  2012           29   80   14    2.0  48.7  2.2   7.6  0.3  2.6
# 3    4      6  2012           30   64   14    0.0  79.4  5.2  15.4  2.2  5.6
# 4    5      6  2012           32   60   14    0.2  77.1  6.0  17.6  1.8  6.5
#
#    FWI    Classes
# 0  0.2  not fire
# 1  0.2  not fire
# 2  0.1  not fire
# 3    1  not fire
# 4  0.9  not fire

# %%
dataset=pd.concat([df,df1])

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 243 entries, 0 to 121
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4    RH          243 non-null    int64
#  5    Ws          243 non-null    int64
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    object
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    object
#  13  Classes      242 non-null    object
# dtypes: float64(5), int64(6), object(3)
# memory usage: 28.5+ KB

# %%
dataset.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
#  RH            0
#  Ws            0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        1
# dtype: int64

# %%
dataset[dataset['Classes  '].isnull()==True]
# Out:
#     day  month  year  Temperature   RH   Ws  Rain   FFMC   DMC      DC   ISI  \
# 43   14      7  2012           37   37   18    0.2  88.9  12.9  14.6 9  12.5
#
#      BUI      FWI Classes
# 43  10.4  fire          NaN

# %%
dataset.dropna(inplace=True).reset_index()
# Out:
#      index  day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  \
# 0        0    1      6  2012           32  71  12   0.7  57.1   2.5   8.2
# 1        1    2      6  2012           30  73  13   4.0  55.7   2.7   7.8
# 2        2    3      6  2012           29  80  14   2.0  48.7   2.2   7.6
# 3        3    4      6  2012           30  64  14   0.0  79.4   5.2  15.4
# 4        4    5      6  2012           32  60  14   0.2  77.1   6.0  17.6
# ..     ...  ...    ...   ...          ...  ..  ..   ...   ...   ...   ...
# 237    117   26      9  2012           30  65  14   0.0  85.4  16.0  44.5
# 238    118   27      9  2012           28  87  15   4.4  41.1   6.5     8
# 239    119   28      9  2012           27  87  29   0.5  45.9   3.5   7.9
# 240    120   29      9  2012           24  54  18   0.1  79.7   4.3  15.2
# 241    121   30      9  2012           24  64  15   0.2  67.3   3.8  16.5
#
#      ISI   BUI  FWI       Classes
# 0    0.6   2.8  0.2   not fire
# ...

# %%
dataset.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes'],
#       dtype='object')

# %%
dataset.columns=dataset.columns.str.strip()

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 243 entries, 0 to 121
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    int64
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    object
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    object
#  13  Classes      242 non-null    object
# dtypes: float64(5), int64(6), object(3)
# memory usage: 28.5+ KB

# %%
dataset.select_dtypes(include='O').columns
# Out:
# Index(['DC', 'FWI', 'Classes'], dtype='object')

# %%
dataset[['DC','FWI']]=dataset[['DC','FWI']].astype('float64')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 242 entries, 0 to 121
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          242 non-null    int64
#  1   month        242 non-null    int64
#  2   year         242 non-null    int64
#  3   Temperature  242 non-null    int64
#  4   RH           242 non-null    int64
#  5   Ws           242 non-null    int64
#  6   Rain         242 non-null    float64
#  7   FFMC         242 non-null    float64
#  8   DMC          242 non-null    float64
#  9   DC           242 non-null    float64
#  10  ISI          242 non-null    float64
#  11  BUI          242 non-null    float64
#  12  FWI          242 non-null    float64
#  13  Classes      242 non-null    object
# dtypes: float64(7), int64(6), object(1)
# memory usage: 28.4+ KB

# %%
dataset.to_csv('Algerian_forest_fires_dataset_cleaned.csv',index=False)

# %%
df_copy=dataset.drop(columns=['day','month','year'])

# %%
df_copy.reset_index()
# Out:
#      index  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  \
# 0        0           32  71  12   0.7  57.1   2.5   8.2  0.6   2.8  0.2
# 1        1           30  73  13   4.0  55.7   2.7   7.8  0.6   2.9  0.2
# 2        2           29  80  14   2.0  48.7   2.2   7.6  0.3   2.6  0.1
# 3        3           30  64  14   0.0  79.4   5.2  15.4  2.2   5.6  1.0
# 4        4           32  60  14   0.2  77.1   6.0  17.6  1.8   6.5  0.9
# ..     ...          ...  ..  ..   ...   ...   ...   ...  ...   ...  ...
# 237    117           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5
# 238    118           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0
# 239    119           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2
# 240    120           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7
# 241    121           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5
#
#           Classes
# 0     not fire
# 1     not fire
# 2     not fire
# 3     not fire
# 4     not fire
# ...

# %%
df_copy['Classes'].value_counts()
# Out:
# 1    156
# 0     86
# Name: Classes, dtype: int64

# %%
df_copy['Classes']=np.where(df_copy['Classes'].str.contains('not fire'),0,1)

# %%
df_copy.hist(bins=50,figsize=(20,15))
plt.show()

# %%
df_copy['Classes'].value_counts().plot(kind='pie',autopct='%.2f%%')
# Out:
# <Axes: ylabel='Classes'>

# %%
df_copy.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.594127 -0.270491 -0.127553  0.571143  0.394472
# RH             -0.594127  1.000000  0.154297  0.146750 -0.644134 -0.384730
# Ws             -0.270491  0.154297  1.000000 -0.137527 -0.025478  0.031887
# Rain           -0.127553  0.146750 -0.137527  1.000000 -0.509872 -0.349583
# FFMC            0.571143 -0.644134 -0.025478 -0.509872  1.000000  0.584221
# DMC             0.394472 -0.384730  0.031887 -0.349583  0.584221  1.000000
# DC              0.292707 -0.275144  0.023962 -0.347646  0.486333  0.882487
# ISI             0.535954 -0.691191  0.128558 -0.412636  0.752513  0.631017
# BUI             0.373088 -0.367170  0.033553 -0.359493  0.580449  0.987926
# FWI             0.500971 -0.605856  0.106128 -0.410213  0.719593  0.852193
# Classes         0.498754 -0.440500  0.046994 -0.474590  0.795500  0.537094
#
#                    DC       ISI       BUI       FWI   Classes
# ...

# %%
sns.heatmap(df_copy.corr())
# Out:
# <Axes: >

# %%
sns.boxplot(df['FWI'],color='green')
# Out:
# <Axes: >

# %%
dataset['Classes']=np.where(dataset['Classes'].str.contains('not fire'),'not fire','fire')

# %%
sns.countplot(x='month',hue='Classes',data=dataset)
# Out:
# <Axes: xlabel='month', ylabel='count'>
